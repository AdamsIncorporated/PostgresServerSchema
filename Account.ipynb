# %%
import sqlite3
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect("main.db")

# %%
account_raw = pd.read_csv(r"./source/Account.csv")
account_ownership_raw = pd.read_csv(r"./source/AccountOwnership.csv")

# %%
account_ownership_raw.head()
# Out:
#   Account No  Chart Id                  Description     Node Type  Image  \
# 0        NaN       NaN               Ownership Root          Root     58
# 1        NaN       NaN                 Unowned Root  UnOwned Root     58
# 2      11000       1.0  Cash - Operating Acct #8854          Data     59
# 3      11100       1.0   Cash - Disburse Acct #0376          Data     59
# 4      11200       1.0   Cash - Disbursement Manual          Data     59
#
#    Calc 1  Calc 2  Calc 3  Ownership Id  Seq No    Key Id Parent Key Id
# 0     NaN     NaN     NaN           142     1.0     $ROOT           NaN
# 1     NaN     NaN     NaN           142     0.5  $UNOWNED             0
# 2     NaN     NaN     NaN           142     1.0   1_11000        1_CASH
# 3     NaN     NaN     NaN           142     2.0   1_11100        1_CASH
# 4     NaN     NaN     NaN           142     3.0   1_11200        1_CASH

# %%
account_raw.head()
# Out:
#    Chart Id Account No                                            Account  \
# 0       1.0      12600  Investments Contra to 1201-Unrealized adjustme...
# 1       1.0      12900  Contra Investments - restricted for capital ac...
# 2       1.0     RSTINV                      RESTRICTED CASH & INVESTMENTS
# 3       1.0      12010                        Investment - TexPool - LPPF
# 4       1.0      12020                         Investment - TexPool - COs
#
#   Account Type              DR/CR Posting Level Inter-Company Flag  \
# 0        Asset  Both Debit/Credit       Allowed           Disabled
# 1        Asset  Both Debit/Credit       Allowed           Disabled
# 2        Asset  Both Debit/Credit    Restricted           Disabled
# 3        Asset  Both Debit/Credit       Allowed           Disabled
# 4        Asset  Both Debit/Credit       Allowed           Disabled
#
#   Security Status  Revaluation  Reconciliation Account Control Class  \
# 0       Unsecured          0.0             0.0                   BAL
# 1       Unsecured          0.0             0.0                   BAL
# 2       Unsecured          0.0             0.0                   BAL
# 3       Unsecured          0.0             0.0                   BAL
# 4       Unsecured          0.0             0.0                   BAL
#
#   Class Description  Conversion Type Id  Conversion Type Description  UDF 1  \
# 0     BALANCE SHEET                 NaN                          NaN    NaN
# 1     BALANCE SHEET                 NaN                          NaN    NaN
# 2     BALANCE SHEET                 NaN                          NaN    NaN
# 3     BALANCE SHEET                 NaN                          NaN    NaN
# 4     BALANCE SHEET                 NaN                          NaN    NaN
#
#    XBRL Tag User Created Date Created
# 0       NaN      MANAGER   12/06/2022
# 1       NaN      MANAGER   12/06/2022
# 2       NaN      MANAGER   12/06/2022
# 3       NaN      MANAGER   12/06/2022
# 4       NaN      MANAGER   12/06/2022

# %% [markdown]
# # Import Account

# %%
account_df = account_raw.copy()
account_df.columns = account_df.columns.str.replace(" ", "")
account_df.columns = account_df.columns.str.replace("-", "")
account_df.dropna(inplace=True, subset='ChartId')
account_df['ChartId'] = account_df['ChartId'].astype(int)
account_df.head()
# Out:
#    ChartId AccountNo                                            Account  \
# 0        1     12600  Investments Contra to 1201-Unrealized adjustme...
# 1        1     12900  Contra Investments - restricted for capital ac...
# 2        1    RSTINV                      RESTRICTED CASH & INVESTMENTS
# 3        1     12010                        Investment - TexPool - LPPF
# 4        1     12020                         Investment - TexPool - COs
#
#   AccountType              DR/CR PostingLevel InterCompanyFlag SecurityStatus  \
# 0       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
# 1       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
# 2       Asset  Both Debit/Credit   Restricted         Disabled      Unsecured
# 3       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
# 4       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
#
#    Revaluation  Reconciliation AccountControlClass ClassDescription  \
# 0          0.0             0.0                 BAL    BALANCE SHEET
# 1          0.0             0.0                 BAL    BALANCE SHEET
# 2          0.0             0.0                 BAL    BALANCE SHEET
# 3          0.0             0.0                 BAL    BALANCE SHEET
# 4          0.0             0.0                 BAL    BALANCE SHEET
#
#    ConversionTypeId  ConversionTypeDescription  UDF1  XBRLTag UserCreated  \
# 0               NaN                        NaN   NaN      NaN     MANAGER
# 1               NaN                        NaN   NaN      NaN     MANAGER
# 2               NaN                        NaN   NaN      NaN     MANAGER
# 3               NaN                        NaN   NaN      NaN     MANAGER
# 4               NaN                        NaN   NaN      NaN     MANAGER
#
#   DateCreated
# 0  12/06/2022
# 1  12/06/2022
# 2  12/06/2022
# 3  12/06/2022
# 4  12/06/2022

# %% [markdown]
# # Import Account_RadType

# %%
account_ownership_df = account_ownership_raw.copy()
account_ownership_df.columns = account_ownership_df.columns.str.replace(" ", "")
account_ownership_df.dropna(inplace=True, subset='AccountNo')
account_ownership_df = account_ownership_df[['AccountNo', 'ParentKeyId']]
account_ownership_df['ParentKeyId'] = account_ownership_df['ParentKeyId'].str.replace('1_', "")
merge = pd.merge(account_df, account_ownership_df, on="AccountNo")
merge.rename(columns={'ParentKeyId': 'ParentAccountNo'}, inplace=True)
merge.head(2)
# Out:
#    ChartId AccountNo                                            Account  \
# 0        1     12600  Investments Contra to 1201-Unrealized adjustme...
# 1        1     12900  Contra Investments - restricted for capital ac...
#
#   AccountType              DR/CR PostingLevel InterCompanyFlag SecurityStatus  \
# 0       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
# 1       Asset  Both Debit/Credit      Allowed         Disabled      Unsecured
#
#    Revaluation  Reconciliation AccountControlClass ClassDescription  \
# 0          0.0             0.0                 BAL    BALANCE SHEET
# 1          0.0             0.0                 BAL    BALANCE SHEET
#
#    ConversionTypeId  ConversionTypeDescription  UDF1  XBRLTag UserCreated  \
# 0               NaN                        NaN   NaN      NaN     MANAGER
# 1               NaN                        NaN   NaN      NaN     MANAGER
#
#   DateCreated ParentAccountNo
# 0  12/06/2022       INVESTMNT
# 1  12/06/2022       INVESTMNT

# %%
def import_func(df: pd.DataFrame()) -> None:
    df.to_sql('Account', conn, if_exists='append', index=False)
    
# import_func(merge)
