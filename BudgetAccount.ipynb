# %%
import sqlite3
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %%
conn = sqlite3.connect("main.db")

# %%
raw = pd.read_csv(r"./source/BudgetAccount.csv")

# %%
df = raw.copy()
df = df.reset_index(drop=True)
df.columns = df.columns.str.replace(' ', "")
df['Id'] = df.index + 1
df
# Out:
#     DisplayOrder AccountNo                            Account  \
# 0              1     50000                           Salaries
# 1              2     50000                           Salaries
# 2              3     51000                   Contracted Labor
# 3              4    SALWAG      SALARIES WAGES CONTRACT LABOR
# 4              5     52500                 Employee Relations
# ..           ...       ...                                ...
# 72            73     75000  Professional Development Subtotal
# 73            74     76000            Sponsorship/Benefaction
# 74            75     79000                          Insurance
# 75            76    OTHG&S           OTHER GOODS AND SERVICES
# 76            77  TOTOPEXP            TOTAL OPERATING EXPENSE
#
#                            RAD CreatedDate  Id
# 0                      Regular   10/7/2024   1
# 1                     Overtime   10/7/2024   2
# 2                          NaN   10/7/2024   3
# 3                          NaN   10/7/2024   4
# 4                          NaN   10/7/2024   5
# ..                         ...         ...  ..
# 72  Prof Development Flat View   10/7/2024  73
# 73                         NaN   10/7/2024  74
# 74                         NaN   10/7/2024  75
# 75                         NaN   10/7/2024  76
# 76                         NaN   10/7/2024  77
#
# [77 rows x 6 columns]
