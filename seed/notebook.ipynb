# %%
import pandas as pd

# %%
df = pd.read_csv('jt.csv')
df = df[df['Account No'].isin([45200, 45600, 45100, 45400, 45000, 45300, 45500])] 
df.head()
# Out:
# C:\Users\adamss\AppData\Local\Temp\ipykernel_9212\992162928.py:1: DtypeWarning: Columns (2,5,7,9,12,14,16,22,23,24,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('jt.csv')
#         Entry Id  Business Unit Id Account No       Amount Accounting Date  \
# 132412      5360              5200      45100   447,609.02      07/31/2023
# 132414      5360              5200      45100  -531,170.39      07/31/2023
# 132415      5360              5200      45500   -17,403.04      07/31/2023
# 132416      5360              5200      45500   -59,821.32      07/31/2023
# 132417      5360              5200      45500       188.07      07/31/2023
#
#        CVS RAD PROJ RAD GRNT RAD  PTAR RAD CIP RAD  ... PUBR RAD  FAC RAD  \
# 132412     NaN      NaN      NaN       NaN     NaN  ...      NaN      NaN
# 132414     NaN      NaN      NaN       NaN     NaN  ...      NaN      NaN
# ...
