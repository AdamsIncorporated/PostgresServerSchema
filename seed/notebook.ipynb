# %%
import pandas as pd

# %%
df = pd.read_csv('bt.csv')
df = df[df['Account No.'] == 45100]
df
# Out:
# C:\Users\adamss\AppData\Local\Temp\ipykernel_26368\565215550.py:1: DtypeWarning: Columns (32,33,41,44,51,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('bt.csv')
#       Budget Id  Business Unit Id  Chart Id  Account No.           Amount  \
# 4356       FY21              5200         1        45100  -234,057,519.37
# 4357       FY21              5200         1        45100             0.00
# 4358       FY21              5200         1        45100             0.00
# 4359       FY21              5200         1        45100             0.00
# 4360       FY21              5200         1        45100             0.00
# 4361       FY21              5200         1        45100             0.00
# 4362       FY21              5200         1        45100             0.00
# 4363       FY21              5200         1        45100             0.00
# 4364       FY21              5200         1        45100             0.00
# ...
